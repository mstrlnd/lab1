# %%
#imports
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# %%
#load data
df = pd.read_csv('cdc.csv')
#number of rows of data and the number of variables - How many rows are there?  How many variables?
df.shape
# Out:
# (15624, 33)

# %%
#preview the first 5 rows of data (some variables might get cut off)
df.head()
# Out:
#    Unnamed: 0           age  gender       grade hisp_latino  \
# 0           1  16 years old    Male  11th grade          No
# 1           2  16 years old  Female  11th grade         Yes
# 2           3  17 years old    Male  12th grade          No
# 3           4  17 years old    Male  12th grade          No
# 4           5  16 years old  Female  11th grade          No
#
#                            race  height  weight                  helmet  \
# 0     Black or African American    1.73   54.43     Never wore a helmet
# 1  Multiple - Hispanic / Latino    1.50   51.26     Never wore a helmet
# 2                         White    1.90   66.68  Did not ride a bicycle
# 3                         White     NaN     NaN     Never wore a helmet
# 4                         White    1.63   68.49  Did not ride a bicycle
#
#           seat_belt  ... eat_breakfast days_exercise_60  \
# 0            Always  ...        3 days           5 days
# 1            Always  ...        7 days           3 days
# 2            Always  ...        5 days           3 days
# 3            Always  ...        2 days           2 days
# 4  Most of the time  ...        0 days           0 days
#
#                       hours_tv                 hours_videogame number_teams  \
# 0              3 hours per day         5 or more hours per day      0 teams
# 1                          NaN  No playing video/computer game      0 teams
# 2  No TV on average school day                 4 hours per day      0 teams
# 3              2 hours per day                 3 hours per day       1 team
# 4     Less than 1 hour per day        Less than 1 hour per day      0 teams
#
#   asthma      hours_sleep           drink_sportsdrink  \
# 0     No          7 hours  Did not drink sports drink
# 1     No          8 hours  Did not drink sports drink
# 2    NaN          8 hours  Did not drink sports drink
# 3     No          6 hours                1 to 3 times
# 4     No  4 or less hours                1 to 3 times
#
#                drink_water sunburns
# 0           1 time per day  0 times
# 1          2 times per day  0 times
# 2  4 or more times per day  2 times
# 3           1 time per day  0 times
# 4  4 or more times per day  1 times
#
# [5 rows x 33 columns]

# %%
#list all the variables
list(df)
# Out:
# ['Unnamed: 0',
#  'age',
#  'gender',
#  'grade',
#  'hisp_latino',
#  'race',
#  'height',
#  'weight',
#  'helmet',
#  'seat_belt',
#  'drive_text',
#  'fights',
#  'bully_school',
#  'bully_electronic',
#  'depressed',
#  'days_smoking',
#  'days_vaping',
#  'describe_weight',
#  'drink_juice',
#  'eat_fruit',
#  'eat_salad',
#  'drink_soda',
#  'drink_milk',
#  'eat_breakfast',
#  'days_exercise_60',
#  'hours_tv',
#  'hours_videogame',
#  'number_teams',
#  'asthma',
#  'hours_sleep',
#  'drink_sportsdrink',
#  'drink_water',
#  'sunburns']

# %%
#Check the datatypes.  "object" is categorical.  "int64" and "float64" are numerical 
df.dtypes
# Out:
# Unnamed: 0             int64
# age                   object
# gender                object
# grade                 object
# hisp_latino           object
# race                  object
# height               float64
# weight               float64
# helmet                object
# seat_belt             object
# drive_text            object
# fights                object
# bully_school          object
# bully_electronic      object
# depressed             object
# days_smoking          object
# days_vaping           object
# describe_weight       object
# drink_juice           object
# eat_fruit             object
# eat_salad             object
# drink_soda            object
# drink_milk            object
# eat_breakfast         object
# days_exercise_60      object
# hours_tv              object
# hours_videogame       object
# number_teams          object
# asthma                object
# hours_sleep           object
# drink_sportsdrink     object
# drink_water           object
# sunburns              object
# dtype: object

# %%
#See the different categories for a categorial variable
df['eat_fruit'].value_counts()
# Out:
# 1 to 3 times               5228
# 4 to 6 times               3396
# 2 times per day            1659
# Did not eat fruit          1643
# 1 time per day             1608
# 4 or more times per day    1028
# 3 times per day             772
# Name: eat_fruit, dtype: int64

# %%
#How to make a bargraph
sns.countplot(data=df, x='eat_fruit')
# Out:
# <AxesSubplot:xlabel='eat_fruit', ylabel='count'>

# %%
#to rotate the labels, you have to save the graph in the variable "plot" and then rotate the labels
plot = sns.countplot(data=df, x='eat_fruit')
plot.set_xticklabels(plot.get_xticklabels(), rotation=75)
# Out:
# [Text(0, 0, '1 time per day'),
#  Text(1, 0, '1 to 3 times'),
#  Text(2, 0, '4 to 6 times'),
#  Text(3, 0, '4 or more times per day'),
#  Text(4, 0, '3 times per day'),
#  Text(5, 0, 'Did not eat fruit'),
#  Text(6, 0, '2 times per day')]

# %%
#How to make a side by side bargraph with the labels roatated
#Vaping broken down by gender
plot = sns.countplot(data=df, x='eat_fruit', hue='gender')
plot.set_xticklabels(plot.get_xticklabels(), rotation=75)
# Out:
# [Text(0, 0, '1 time per day'),
#  Text(1, 0, '1 to 3 times'),
#  Text(2, 0, '4 to 6 times'),
#  Text(3, 0, '4 or more times per day'),
#  Text(4, 0, '3 times per day'),
#  Text(5, 0, 'Did not eat fruit'),
#  Text(6, 0, '2 times per day')]

# %% [markdown]
# This Blocks is just text not code.<br>
# Data Cycle<br>
# Write a Statistical question goes here:<br>
# Make some bargraphs to find your answer.  Don't forget to include your interpretations<br>

# %%
# Out:
#    Unnamed: 0           age  gender       grade hisp_latino  \
# 0           1  16 years old    Male  11th grade          No
# 1           2  16 years old  Female  11th grade         Yes
# 2           3  17 years old    Male  12th grade          No
# 3           4  17 years old    Male  12th grade          No
# 4           5  16 years old  Female  11th grade          No
#
#                            race  height  weight                  helmet  \
# 0     Black or African American    1.73   54.43     Never wore a helmet
# 1  Multiple - Hispanic / Latino    1.50   51.26     Never wore a helmet
# 2                         White    1.90   66.68  Did not ride a bicycle
# 3                         White     NaN     NaN     Never wore a helmet
# 4                         White    1.63   68.49  Did not ride a bicycle
#
#           seat_belt  ... eat_breakfast days_exercise_60  \
# 0            Always  ...        3 days           5 days
# 1            Always  ...        7 days           3 days
# 2            Always  ...        5 days           3 days
# 3            Always  ...        2 days           2 days
# 4  Most of the time  ...        0 days           0 days
#
#                       hours_tv                 hours_videogame number_teams  \
# 0              3 hours per day         5 or more hours per day      0 teams
# 1                          NaN  No playing video/computer game      0 teams
# 2  No TV on average school day                 4 hours per day      0 teams
# 3              2 hours per day                 3 hours per day       1 team
# 4     Less than 1 hour per day        Less than 1 hour per day      0 teams
#
#   asthma      hours_sleep           drink_sportsdrink  \
# 0     No          7 hours  Did not drink sports drink
# 1     No          8 hours  Did not drink sports drink
# 2    NaN          8 hours  Did not drink sports drink
# 3     No          6 hours                1 to 3 times
# 4     No  4 or less hours                1 to 3 times
#
#                drink_water sunburns
# 0           1 time per day  0 times
# 1          2 times per day  0 times
# 2  4 or more times per day  2 times
# 3           1 time per day  0 times
# 4  4 or more times per day  1 times
#
# [5 rows x 34 columns]
